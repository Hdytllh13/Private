# %%
import pandas as pd
import numpy as np

# Set random seed
np.random.seed(42)

# Buat baris data karyawan acak
n = 100
df_sample = pd.DataFrame({
    "target_achievement": np.round(np.random.uniform(0.5, 1.5, n), 2),
    "company_tenure_years": np.round(np.random.uniform(0, 15, n), 1),
    "distance_to_office_km": np.round(np.random.uniform(1, 30, n), 1),
    "job_satisfaction": np.random.randint(1, 6, n),
    "manager_support_score": np.random.randint(1, 6, n),
    "marital_status": np.random.choice(["Married", "Single"], n, p=[0.6, 0.4]),
    "working_hours_per_week": np.random.randint(35, 65, n)
})

# Simpan ke file CSV
df_sample.to_csv("employee_sample_100.csv", index=False)

print("✅ File berhasil dibuat: employee_sample_100.csv")
print(df_sample.head())
# Out:
# ✅ File berhasil dibuat: employee_sample_100.csv
#    target_achievement  company_tenure_years  distance_to_office_km  \
# 0                0.87                   0.5                   19.6
# 1                1.45                   9.5                    3.4
# 2                1.23                   4.7                    5.7
# 3                1.10                   7.6                   27.1
# 4                0.66                  13.6                   18.6
#
#    job_satisfaction  manager_support_score marital_status  \
# 0                 5                      2        Married
# 1                 4                      2        Married
# 2                 3                      3         Single
# 3                 4                      1        Married
# 4                 5                      4        Married
#
#    working_hours_per_week
# 0                      36
# 1                      56
# 2                      56
# 3                      37
# 4                      61
